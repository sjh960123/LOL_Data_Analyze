# %%
import pandas as pd
import time
import json
import requests
from tqdm import tqdm_notebook

api_url='http://ddragon.leagueoflegends.com/cdn/10.6.1/data/en_US/champion.json'
r=requests.get(api_url)
champ=r.json()

# %%
champ_df=pd.DataFrame(champ['data']).T
champ_df.reset_index(inplace=True)
champ_df.drop('index',1,inplace=True)
champ_df
# Out:
#     version       id  key     name                   title  \
# 0    10.6.1   Aatrox  266   Aatrox        the Darkin Blade
# 1    10.6.1     Ahri  103     Ahri     the Nine-Tailed Fox
# 2    10.6.1    Akali   84    Akali      the Rogue Assassin
# 3    10.6.1  Alistar   12  Alistar            the Minotaur
# 4    10.6.1    Amumu   32    Amumu           the Sad Mummy
# ..      ...      ...  ...      ...                     ...
# 143  10.6.1      Zed  238      Zed   the Master of Shadows
# 144  10.6.1    Ziggs  115    Ziggs  the Hexplosives Expert
# 145  10.6.1   Zilean   26   Zilean        the Chronokeeper
# 146  10.6.1      Zoe  142      Zoe  the Aspect of Twilight
# 147  10.6.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                  blurb  \
# 0    Once honored defenders of Shurima against the ...
# 1    Innately connected to the latent power of Rune...
# 2    Abandoning the Kinkou Order and her title of t...
# ...

# %%
tmp=pd.DataFrame()
for i in range(len(champ_df['stats'])):
    a=dict(champ_df['stats'][i])
    b=pd.DataFrame(a,index=[i])
    tmp=pd.concat([tmp,b])
tmp
# Out:
#          hp  hpperlevel     mp  mpperlevel  movespeed   armor  armorperlevel  \
# 0    580.00          90    0.0         0.0        345  38.000           3.25
# 1    526.00          92  418.0        25.0        330  20.880           3.50
# 2    575.00          95  200.0         0.0        345  23.000           3.50
# 3    600.00         106  350.0        40.0        330  44.000           3.50
# 4    613.12          84  287.2        40.0        335  33.000           3.80
# ..      ...         ...    ...         ...        ...     ...            ...
# 143  584.00          85  200.0         0.0        345  32.000           3.50
# 144  536.00          92  480.0        23.5        325  21.544           3.30
# 145  504.00          82  452.0        30.0        335  24.000           3.80
# 146  560.00          92  425.0        25.0        340  20.800           3.50
# 147  504.00          79  418.0        25.0        340  29.000           3.00
#
# ...

# %%
champ_df=pd.DataFrame({
    'version':champ_df['version'],
    'name':champ_df['id'],
    'champId':champ_df['key']
})
champ_df
# Out:
#     version     name champId
# 0    10.6.1   Aatrox     266
# 1    10.6.1     Ahri     103
# 2    10.6.1    Akali      84
# 3    10.6.1  Alistar      12
# 4    10.6.1    Amumu      32
# ..      ...      ...     ...
# 143  10.6.1      Zed     238
# 144  10.6.1    Ziggs     115
# 145  10.6.1   Zilean      26
# 146  10.6.1      Zoe     142
# 147  10.6.1     Zyra     143
#
# [148 rows x 3 columns]

# %%
champ=pd.concat([champ_df,tmp],1)
champ
# Out:
#     version     name champId      hp  hpperlevel     mp  mpperlevel  \
# 0    10.6.1   Aatrox     266  580.00          90    0.0         0.0
# 1    10.6.1     Ahri     103  526.00          92  418.0        25.0
# 2    10.6.1    Akali      84  575.00          95  200.0         0.0
# 3    10.6.1  Alistar      12  600.00         106  350.0        40.0
# 4    10.6.1    Amumu      32  613.12          84  287.2        40.0
# ..      ...      ...     ...     ...         ...    ...         ...
# 143  10.6.1      Zed     238  584.00          85  200.0         0.0
# 144  10.6.1    Ziggs     115  536.00          92  480.0        23.5
# 145  10.6.1   Zilean      26  504.00          82  452.0        30.0
# 146  10.6.1      Zoe     142  560.00          92  425.0        25.0
# 147  10.6.1     Zyra     143  504.00          79  418.0        25.0
#
#      movespeed   armor  armorperlevel  ...  hpregen  hpregenperlevel  mpregen  \
# ...

# %%
champ.to_csv('D:/Final_Project/data/champion_20.csv',encoding='utf-8-sig')
