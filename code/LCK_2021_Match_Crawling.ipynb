# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\yibob\\Anaconda3\\final_project\\Final\\using_code\\뻐꾸기'

# %% [markdown]
# # gamepedia 에서 match_link 크롤링

# %%
from selenium import webdriver
import time
# import openpyxl
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from selenium.common.exceptions import NoSuchElementException
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# <pre>
# https://lol.fandom.com/wiki/League_of_Legends_Esports_Wiki
# https://lol.fandom.com/wiki/2021_Season
# https://lol.fandom.com/wiki/LCK/2021_Season
# https://lol.fandom.com/wiki/LCK/2021_Season/Spring_Season
# </pre>

# %%
driver = webdriver.Chrome('../../driver/chromedriver.exe')
# 실제 브라우저, 브라우저 조종 권한 생김.
url_base = 'https://lol.fandom.com/wiki/'
url = 'https://lol.fandom.com/wiki/LCK/2021_Season'

driver.get(url)
# 2021년 lck 리그 정보 overview

time.sleep(3)

# %%
season_list = driver.find_elements_by_css_selector('div.tabheader-top div.tabheader-tab a')
season_url_list = []

f = open(url.replace(url_base, '').replace('/', '') + '.txt', 'w')
f.close()

# %%
## spring , spring_playoff , summor, summor_playoff 들어있는 리스트 가져오기.
season_list = driver.find_elements_by_css_selector('div.tabheader-top div.tabheader-tab a')
season_url_list = []

f = open(url.replace(url_base, '').replace('/', '') + '.txt', 'w')

for season_url in season_list:
    # print(season_url.get_attribute('href'))
    season_url_list.append(season_url.get_attribute('href'))

for season in season_url_list[1:]:

    f.write('url_' + season.replace(url_base, '').replace('/', '') + '.txt')
    f.write('\n')

    t = open('url_' + season.replace(url_base, '').replace('/', '') + '.txt', 'w')

    driver.get(season)

    time.sleep(2)
    
    try: vodlinks = driver.find_element_by_css_selector('span.mdv-showbuttons').click()
    except NoSuchElementException: # 21시즌은 진행중이므로 match링크를 찾을 수 없는 것은 예외처리
        pass
    
    containers = driver.find_elements_by_css_selector('div.mw-parser-output table#md-table tbody tr')

    for container in containers[3:]:
        tds_a = container.find_elements_by_css_selector('td a')
        for a in tds_a:
            if a.text == 'Link' and 'matchhistory' in a.get_attribute('href'):
                print(a.get_attribute('href'))
                t.write(a.get_attribute('href'))
                t.write('\n')

    t.close()

f.close()
# Out:
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690520?gameHash=04199edf6922bed2
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690549?gameHash=12e7e73be0bdaa47
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690563?gameHash=d4c803833c6e8644
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690580?gameHash=9d098c346884254e
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690585?gameHash=c8661864a85ce53a
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690820?gameHash=fd0b28d1ae633da9
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690828?gameHash=d5fc3d0477233ff4
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690841?gameHash=187b8779c2c7426b
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/1681444?gameHash=3ece5d9433401707
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/1681477?gameHash=5da6773ada18612f
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/1681511?gameHash=8e14d7092c466162
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691020?gameHash=3a20c6080120cfa5
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691048?gameHash=88451f57741979af
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691071?gameHash=6fd99dcd159834fe
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691105?gameHash=e7de9b7d94c6972a
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691118?gameHash=bd5a36f21b7bacca
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691379?gameHash=d598a4558e969372
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691409?gameHash=f0ae9efe8c0b8823
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691411?gameHash=78512c3dd1a3b026
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691433?gameHash=a491773a6c17f21b
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1691436?gameHash=8810d76daf71d26b
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2139392?gameHash=799726de90f1bd8e
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2149608?gameHash=d06321cf040bd408
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2149614?gameHash=bdd22e6ff85ff995
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2139470?gameHash=83fe5c17f9b1cb68
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2149659?gameHash=29d4af3593ad2e93
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2149661?gameHash=2f709a71adc4af12
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2149673?gameHash=9f3e0fa27193afa3
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/2149710?gameHash=2958668c0244c995
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2064994?gameHash=6cd4ffadc13d7179
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065053?gameHash=262077dd98de2aa2
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065058?gameHash=5f36317913e27542
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065070?gameHash=6165daedf6d6b018
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065135?gameHash=cc1bc4aad1d6e877
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065175?gameHash=cc26ce6e196062de
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065518?gameHash=777241e0a713a07f
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065576?gameHash=68e61d394b4be26f
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065580?gameHash=a72acd4814ba18e2
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2075641?gameHash=d0fb12d1f3aabac2
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065618?gameHash=fa86dcc436bea990
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065870?gameHash=6d8d54198de38b05
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065926?gameHash=a6e9dd21d1d40f8b
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065932?gameHash=b96a31b99ce0c597
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065983?gameHash=23002f0da9b476b0
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2065992?gameHash=c076694a984ebfcf
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2066223?gameHash=a71048f7d692afae
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2076321?gameHash=9b6bbf96edb8bb94
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2076330?gameHash=dbf01fc26b59b9e7
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2076346?gameHash=5cee2e40ffe10703
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2076383?gameHash=0c53482ad90dace7
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2076419?gameHash=5fff62906b2d5417
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067168?gameHash=5642c218bd1cf3a5
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067194?gameHash=4c75ad22aaaa5638
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067197?gameHash=3df7ebb4259edf04
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067212?gameHash=265f310fab6f5ccf
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067242?gameHash=4cf6f97f89285ebb
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067349?gameHash=a4bb5e442846039e
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067383?gameHash=8e076272eed5f389
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067393?gameHash=ede1f8c032110998
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2077519?gameHash=d02dde8e9b024c73
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2077555?gameHash=196f5d2c7b9a9336
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067487?gameHash=ee35a800cf7c3016
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067520?gameHash=199698b4b913865d
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067527?gameHash=ecd57b865a17b62c
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067532?gameHash=867f551ee2ac422b
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067551?gameHash=8c6fdc33fdd7023f
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067557?gameHash=f2106b105416002b
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067583?gameHash=2018c9643de0e01e
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067610?gameHash=2d90eaf0aa4f42fd
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067619?gameHash=b6bbabafdaf66b21
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067624?gameHash=43c3bc68debc9a09
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT02/2067650?gameHash=0d9546d2d7b4e773
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/2073777?gameHash=a15b6e5037799487
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/2073826?gameHash=5f5ba8091aab21e6
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/2073841?gameHash=f114861eae2db9f4
# http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT03/2073893?gameHash=d9421f3232e02a5c

# %%
driver.close()

# %% [markdown]
# # 크롤링해온 match_link로 match정보 크롤링

# %%
from selenium import webdriver
import time
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from selenium.webdriver.common.by import By
# WebDriverWait는 Selenium 2.4.0 이후 부터 사용 가능합니다.
from selenium.webdriver.support.ui import WebDriverWait
# expected_conditions는 Selenium 2.26.0 이후 부터 사용 가능합니다.
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
filenames = open('LCK2021_Season.txt', 'r')
#season names

for filename in filenames:
    pagesources = open(filename.strip(), 'r')

    wb = openpyxl.Workbook()

    sheet = wb.active

    options = webdriver.ChromeOptions()
    prefs = {"profile.managed_default_content_settings.images": 2}

    options.add_experimental_option("prefs", prefs)

    # options.add_argument('headless')

    options.add_argument('window-size=1920x1080')

    driver = webdriver.Chrome('../../driver/chromedriver.exe', options=options)

    i = 0

    # 로그인 먼저 해보기.
    driver = webdriver.Chrome('../../driver/chromedriver.exe', options=options)
    driver.get('http://matchhistory.na.leagueoflegends.com/en/#match-details/ESPORTSTMNT01/1690520?gameHash=04199edf6922bed2')
    time.sleep(3)

    lolid = '롤 아이디'
    input_id = driver.find_elements_by_css_selector('input.field__form-input.text__ignore-subset')[0]
    input_id.send_keys(lolid)


    lolpassword = '롤 비번'
    input_pw = driver.find_elements_by_css_selector('input.field__form-input.text__ignore-subset')[1]
    input_pw.clear()
    input_pw.send_keys(lolpassword)

    driver.find_element_by_css_selector('label.signin-checkbox').click()

    driver.find_element_by_css_selector('button.mobile-button').click()
    time.sleep(5)
    
    for pagesource in pagesources:
        i = i+1

        pagesource = pagesource.replace('&tab=overview', '')

        pagesource = pagesource + '&tab=overview'


        while True:

            teamlist = []
            team1list = []
            team2list = []

            team1top = []
            team1jg = []
            team1mid = []
            team1ad = []
            team1sp = []
            team1 = [team1top, team1jg, team1mid, team1ad, team1sp]

            team2top = []
            team2jg = []
            team2mid = []
            team2ad = []
            team2sp = []
            team2 = [team2top, team2jg, team2mid, team2ad, team2sp]

            try:
                driver.get(pagesource)
                time.sleep(1)
                containers = driver.find_elements_by_css_selector('div.section-wrapper-content-wrapper div#main div.classic.details > div')
                # head , body , tail 전의 제일 큰 컨테이너

                ## head 부분에서 경기 날짜, 시간 가져오기
                head = containers[0].find_element_by_css_selector('div.gs-container')
                gameduration = head.find_element_by_css_selector('span.map-header-duration').text
                gamedate = head.find_element_by_css_selector('span.map-header-date').text
                print(gamedate, gameduration)
                teamlist.append(gamedate)
                teamlist.append(gameduration)

                ## body 부분에서 경기 내용 가져오기.
                body = containers[1].find_elements_by_css_selector('div.scoreboard > div > div > div > div')

                ###################### blue team
                    # 전반적 승/패 골드 킬
                team_header = body[0].find_element_by_css_selector('div > header')

                team_result = team_header.find_element_by_css_selector('div.game-conclusion').text.strip()
                team_gold = team_header.find_element_by_css_selector('div.gold').text.strip()
                team_kills = team_header.find_element_by_css_selector('div.kills').text.strip()
                # print(team_result, team_gold, team_kills)
                team1list.append(team_result)
                team1list.append(team_gold)
                team1list.append(team_kills)



                    # 챔피언 소환사주문 선수이름
                team_bodys = body[0].find_elements_by_css_selector('ul.grid-list > li')
                        # 선수 1명
                        # 1번 탑 선수 기준
                # print('team_bodys counts')
                # print(len(team_bodys))

                for teamplayer in team_bodys:
                    # print()
                    index = team_bodys.index(teamplayer)

                    player_name_container = teamplayer.find_element_by_css_selector('div.name')
                                # 챔피언 이름, 챔피언 레벨
                    champion_name = player_name_container.find_element_by_css_selector('div.champion-icon > div')
                    champ_name = champion_name.get_attribute('data-rg-id')
                    champ_ver = champion_name.get_attribute('data-rg-name')
                    champ_level = player_name_container.find_element_by_css_selector('span.champion-nameplate-level div.binding').text

                    # print(champ_ver, champ_name, champ_level)

                                # 선수 이름
                    player_name = player_name_container.find_element_by_css_selector('div.champion-nameplate-name > div').text
                    # print(player_name)
                    team1[index].append(player_name)
                    team1[index].append(champ_ver)
                    team1[index].append(champ_name)
                    team1[index].append(champ_level)

                                # 소환사 주문
                    champion_spells = player_name_container.find_elements_by_css_selector('div.spell-book > div')
                    for spell in champion_spells:
                        champion_spells2 = spell.find_element_by_css_selector('div')
                        champion_spell_ver = champion_spells2.get_attribute('data-rg-name')
                        champion_spell = champion_spells2.get_attribute('data-rg-id')
                        # print(champion_spell_ver, champion_spell)
                        team1[index].append(champion_spell_ver)
                        team1[index].append(champion_spell)

                    # 밴, 타워킬, 억제기킬, 바론킬, 드래곤킬, 전령킬
                team_footer = body[0].find_element_by_css_selector('div > footer div.gs-container')

                        # 밴
                team_bans = team_footer.find_elements_by_css_selector('div.champion-nameplate')
                # print()
                # print('bans')


                for ban in team_bans:
                    ban = ban.find_element_by_css_selector('div.champion-icon div')
                    ban_name = ban.get_attribute('data-rg-id')
                    # print(ban_name)
                    team1list.append(ban_name)

                # print()
                        # 타워킬
                team_towerkill = team_footer.find_element_by_css_selector('div.tower-kills').text.strip()
                        # 억제기 킬
                team_inhibitorkill = team_footer.find_element_by_css_selector('div.inhibitor-kills').text.strip()
                        # 바론 킬
                team_baronkill = team_footer.find_element_by_css_selector('div.baron-kills').text.strip()
                        # 드래곤 킬
                team_dragonkill = team_footer.find_element_by_css_selector('div.dragon-kills').text.strip()
                        # 전령 킬
                team_riftkill = team_footer.find_element_by_css_selector('div.rift-herald-kills').text.strip()

                # print('타워킬', team_towerkill)
                # print('억제기 킬', team_inhibitorkill)
                # print('바론 킬', team_baronkill)
                # print('드래곤 킬', team_dragonkill)
                # print('전령 킬', team_riftkill)
                team1list.append(team_towerkill)
                team1list.append(team_inhibitorkill)
                team1list.append(team_baronkill)
                team1list.append(team_dragonkill)
                team1list.append(team_riftkill)

                ####################################### red team
                    # 전반적 승/패 골드 킬
                team_header = body[1].find_element_by_css_selector('div > header')

                team_result = team_header.find_element_by_css_selector('div.game-conclusion').text.strip()
                team_gold = team_header.find_element_by_css_selector('div.gold').text.strip()
                team_kills = team_header.find_element_by_css_selector('div.kills').text.strip()
                # print()
                # print(team_result, team_gold, team_kills)
                team2list.append(team_result)
                team2list.append(team_gold)
                team2list.append(team_kills)

                    # 챔피언 소환사주문 선수이름
                team_bodys = body[1].find_elements_by_css_selector('ul.grid-list > li')
                        # 선수 1명
                        # 1번 탑 선수 기준
                # print('team_bodys counts')
                # print(len(team_bodys))

                for teamplayer in team_bodys:
                    # print()
                    index = team_bodys.index(teamplayer)

                    player_name_container = teamplayer.find_element_by_css_selector('div.name')
                                # 챔피언 이름, 챔피언 레벨
                    champion_name = player_name_container.find_element_by_css_selector('div.champion-icon > div')
                    champ_name = champion_name.get_attribute('data-rg-id')
                    champ_ver = champion_name.get_attribute('data-rg-name')
                    champ_level = player_name_container.find_element_by_css_selector('span.champion-nameplate-level > div.binding').text

                    # print(champ_ver, champ_name, champ_level)


                                # 선수 이름

                    player_name = player_name_container.find_element_by_css_selector('div.champion-nameplate-name > div').text
                    # print(player_name)


                    team2[index].append(player_name)
                    team2[index].append(champ_ver)
                    team2[index].append(champ_name)
                    team2[index].append(champ_level)


                                # 소환사 주문
                    champion_spells = player_name_container.find_elements_by_css_selector('div.spell-book > div')
                    for spell in champion_spells:
                        champion_spells2 = spell.find_element_by_css_selector('div')
                        champion_spell_ver = champion_spells2.get_attribute('data-rg-name')
                        champion_spell = champion_spells2.get_attribute('data-rg-id')
                        # print(champion_spell_ver, champion_spell)
                        team2[index].append(champion_spell_ver)
                        team2[index].append(champion_spell)


                team_footer = body[1].find_element_by_css_selector('div > footer div.gs-container')

                        # 밴
                team_bans = team_footer.find_elements_by_css_selector('div.champion-nameplate')
                # print()
                # print('bans')
                for ban in team_bans:
                    ban = ban.find_element_by_css_selector('div.champion-icon div')
                    ban_name = ban.get_attribute('data-rg-id')
                    # print(ban_name)
                    team2list.append(ban_name)

                # print()
                        # 타워킬
                team_towerkill = team_footer.find_element_by_css_selector('div.tower-kills').text.strip()
                        # 억제기 킬
                team_inhibitorkill = team_footer.find_element_by_css_selector('div.inhibitor-kills').text.strip()
                        # 바론 킬
                team_baronkill = team_footer.find_element_by_css_selector('div.baron-kills').text.strip()
                        # 드래곤 킬
                team_dragonkill = team_footer.find_element_by_css_selector('div.dragon-kills').text.strip()
                        # 전령 킬
                team_riftkill = team_footer.find_element_by_css_selector('div.rift-herald-kills').text.strip()

                # print('타워킬', team_towerkill)
                # print('억제기 킬', team_inhibitorkill)
                # print('바론 킬', team_baronkill)
                # print('드래곤 킬', team_dragonkill)
                # print('전령 킬', team_riftkill)
                team2list.append(team_towerkill)
                team2list.append(team_inhibitorkill)
                team2list.append(team_baronkill)
                team2list.append(team_dragonkill)
                team2list.append(team_riftkill)
            except:
                print('오류')
                wb.save(filename.strip().replace('.txt','.xlsx'))
                driver.refresh()
                time.sleep(2)
                continue
            break

        pagesource = pagesource.replace('overview', 'stats')
        while True:
            try:

                # driver.implicitly_wait(10)
                time.sleep(1)
                driver.get(pagesource)

                time.sleep(1)

                containers2 = driver.find_element_by_css_selector('div.section-wrapper-content-wrapper div#main div.classic.details div.tab-panel-body')
                # head , body , tail 전의 제일 큰 컨테이너

                tail_stats = containers2.find_element_by_css_selector('tbody#stats-body')
                # 통계 tail

                tail_trs = tail_stats.find_elements_by_css_selector('tr.grid-row')

                for tr in tail_trs:
                    tdindex = 0
                    for td in tr.find_elements_by_css_selector('td > div'):
                        # print('tdindex')
                        # print(tdindex)
                        # print(td.text.strip())
                        tdtext = td.text.strip()
                        # tdindex = tr.find_elements_by_css_selector('td div').index(td)
                        if tdindex == 0:
                            pass
                        elif tdindex >= 1 and tdindex <= 5:
                            team1[tdindex-1].append(tdtext)
                        elif tdindex >= 6 and tdindex <= 10:
                            team2[tdindex-6].append(tdtext)
                        tdindex = tdindex + 1

            except:
                print('오류')
                wb.save(filename.strip().replace('.txt','.xlsx'))
                driver.refresh()
                time.sleep(2)
                continue
            break

        while True:
            team11list = []
            team22list = []
            try:
                team11list = teamlist + ['blue'] + team1list
                # sheet.append(teamlist)
                # sheet.append(team1list)
                for player in team1:
                    player = team11list + player
                    sheet.append(player)
                # sheet.append(team2list)
                team22list = teamlist + ['red'] + team2list
                for player in team2:
                    player = team22list + player
                    sheet.append(player)

                print(i)
            except:
                print('오류')
                wb.save(filename.strip().replace('.txt','.xlsx'))
                driver.quit()
                continue
            break

        if i // 5 == 0:
            wb.save(filename.strip().replace('.txt','.xlsx'))

    pagesources.close()

    wb.save(filename.strip().replace('.txt','.xlsx'))

    driver.quit()

filenames.close()
# Out:
# 1/13/2021 36:17
# 1
# 1/13/2021 30:00
# 2
# 1/13/2021 30:49
# 3
# 1/13/2021 29:47
# 4
# 1/13/2021 30:01
# 5
# 1/14/2021 32:19
# 6
# 1/14/2021 26:25
# 7
# 1/14/2021 30:38
# 8
# 1/14/2021 36:02
# 9
# 1/14/2021 29:57
# 10
# 1/14/2021 39:03
# 11
# 1/15/2021 30:35
# 12
# 1/15/2021 27:44
# 13
# 1/15/2021 31:27
# 14
# 1/15/2021 33:22
# 15
# 1/15/2021 41:03
# 16
# 1/16/2021 34:30
# 17
# 1/16/2021 30:50
# 18
# 1/16/2021 27:39
# 19
# 1/16/2021 28:00
# 20
# 1/16/2021 33:04
# 21
# 1/17/2021 28:05
# 22
# 1/17/2021 29:00
# 23
# 1/17/2021 31:14
# 24
# 1/17/2021 40:20
# 25
# 1/20/2021 34:14
# 26
# 1/20/2021 25:54
# 27
# 1/20/2021 31:50
# 28
# 1/20/2021 33:30
# 29
# 1/20/2021 43:08
# 30
# 1/21/2021 37:25
# 31
# 1/21/2021 27:26
# 32
# 1/21/2021 33:58
# 33
# 1/21/2021 36:24
# 34
# 1/21/2021 33:31
# 35
# 1/22/2021 33:21
# 36
# 1/22/2021 34:06
# 37
# 1/22/2021 28:52
# 38
# 1/22/2021 32:23
# 39
# 1/22/2021 22:01
# 40
# 1/22/2021 43:07
# 41
# 1/23/2021 36:56
# 42
# 1/23/2021 25:48
# 43
# 1/23/2021 39:02
# 44
# 1/23/2021 24:43
# 45
# 1/24/2021 34:30
# 46
# 1/24/2021 35:39
# 47
# 1/24/2021 33:42
# 48
# 1/24/2021 33:51
# 49
# 1/24/2021 33:37
# 50
# 1/24/2021 32:10
# 51
# 1/27/2021 32:26
# 52
# 1/27/2021 31:06
# 53
# 1/27/2021 52:40
# 54
# 1/27/2021 30:26
# 55
# 1/27/2021 26:56
# 56
# 1/28/2021 34:34
# 57
# 1/28/2021 30:06
# 58
# 1/28/2021 42:29
# 59
# 오류
# 1/28/2021 33:23
# 60
# 1/29/2021 39:09
# 61
# 1/29/2021 40:27
# 62
# 1/29/2021 34:44
# 63
# 1/29/2021 29:42
# 64
# 1/30/2021 37:54
# 65
# 1/30/2021 29:12
# 66
# 1/30/2021 36:15
# 67
# 1/30/2021 29:49
# 11          Zoe  ...   12   7    -   4  12.0k  11.9k  268   24   14   2
# 12          Zoe  ...    8  14    -   2  10.4k  10.0k  228   16   13   -
# 13          Zoe  ...   48   9    -  22   6.0k   5.8k   28    -    -   -
# 14  TwistedFate  ...    9   4    -   5  14.4k  13.0k  262   16    9   4
# 15  TwistedFate  ...   14   9    -  13  11.3k  10.1k   16  160   91  10
# 16  TwistedFate  ...   15   7    -   5  12.0k  11.4k  211   16   16   -
# 17  TwistedFate  ...   29  13    -   6  16.3k  14.3k  265   30   17   8
# 18  TwistedFate  ...   51  21    -  20   8.4k   6.8k   38    4    -   -
# 19     Renekton  ...   10   3    -   5  11.6k  12.1k  233   11    1   4
# 20     Renekton  ...   14  10    -  13  12.3k  10.9k   26  178  106  21
# 21     Renekton  ...   15   5    -   6  12.4k  10.4k  260   12   12   -
# 22     Renekton  ...   15  16    -   7  14.9k  12.5k  345   18   10   4
# 23     Renekton  ...   48  18    -  16   8.5k   7.3k   45    -    -   -
# 24       Syndra  ...   16   4    -   8   9.0k   8.9k  217    1    1   -
# 25       Syndra  ...    8  10    -   9   8.6k   8.3k   37  157  112   4
# 26       Syndra  ...   17  11    -   7  11.8k  11.0k  316   16   13   -
# 27       Syndra  ...   15   5    -   2  10.7k  10.0k  262   24   21   -
# 28       Syndra  ...   58  17    -  23   5.8k   5.0k   39    -    -   -
# 29       Maokai  ...   13   4    -   8  10.6k   8.8k  193    4    -   -
# 30       Maokai  ...   12  11    -  12  11.5k   9.4k   40  130   89   -
# 31       Maokai  ...   15   7    -   8  13.6k  13.8k  265   40   32   4
# 32       Maokai  ...   18   8    -   1  13.9k  11.5k  253   12    8   -
# 33       Maokai  ...   49  27    -  19   7.2k   6.1k   48    -    -   -
# 34  TwistedFate  ...    9   7    -   3  12.6k  12.5k  259    6    -   5
# 35  TwistedFate  ...   11  21    -  10   9.8k   9.7k   45  160  127   9
# 36  TwistedFate  ...   13   3    -   5   9.6k   9.5k  227   16   11   -
# 37  TwistedFate  ...   14   7    -   6  14.3k  11.9k  277    6    4   2
# 38  TwistedFate  ...   51   9    -  19   6.1k   7.1k   32    -    -   -
# 39         Azir  ...   10   4    -   4  13.4k  12.8k  232   35    7   4
# 40         Azir  ...   15  16    -  14  12.3k  11.4k   43  162   72  39
# 41         Azir  ...   11   2    -   3  14.3k  11.9k  272   19   12   3
# 42         Azir  ...   11  14    -   4  17.1k  13.1k  257   28   20   1
# 43         Azir  ...   47  11    -  19   8.2k   7.6k   40    -    -   -
# 44      Alistar  ...   10   8    -   9   9.1k   9.4k  201    1    1   -
# 45      Alistar  ...    5  13    -   8  10.9k  10.9k   62  105   80  16
# 46      Alistar  ...   19  11    -   8  12.6k  12.2k  221   14   11   -
# 47      Alistar  ...   22  10    -   4  11.9k  11.5k  262   23   22   -
# 48      Alistar  ...   46   6    -  17   6.5k   6.5k   25    -    -   -
# 49      Camille  ...   20  16    -   9  11.4k  10.4k  222   11    3   4
#
# [50 rows x 54 columns]
